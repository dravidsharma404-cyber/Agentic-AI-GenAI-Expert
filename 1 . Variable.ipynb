# %% [raw]
# Variable in python
# >	a variable is a name that refers to a memory location where a value is stored.
# >	a variable is like a container for data

# %% [raw]
# Charcteristic of variable 
# >	Dynamic Typing: no need to declare any variable like (int, float, string)
# >	No Explicit Declaration: Just assign a value, and Python will automatically create the variable
# >	Mutable: You can change the value of a variable as many times as you need during the execution of your program

# %% [raw]
# Rules to define variable in python 
# >	Must start with a letter (a-z, A-Z) or an underscore (_).
# >	Can contain letters, digits (0-9), and underscores, but cannot start with a digit.
# >	Case-sensitive: age, Age, and AGE are different variables.
# >	Cannot be a Python keyword (e.g., True, False, if, for, class, etc.).

# %% [raw]
# Variable_name=Value

# %%
age=30
print(age)
# Out:
# 30

# %%
Age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Age
#
# NameError: name 'Age' is not defined

# %%
AGE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 AGE
#
# NameError: name 'AGE' is not defined

# %%
s1=20
s1
# Out:
# 20

# %%
1s=20
# Out:
#   Cell In[6], line 1
#     1s=20
#     ^
# SyntaxError: invalid decimal literal

# %%
_
# Out:
# '{"dataframes": [], "user": "dravi"}'

# %%
_1='Ram'

# %%
_1
# Out:
# 'Ram'

# %%
@1='shyam'
# Out:
#   Cell In[10], line 1
#     @1='shyam'
#      ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
r_1='Not Defined'
r_1
# Out:
# 'Not Defined'

# %%
# Store value in variable

a=10
b=20

print(a)
print(b)
# Out:
# 10
# 20

# %%
# Using variable expressions
print(a+b)
print(b-a)
print(a*b)
print(b/a)
print(b//a)
# Out:
# 30
# 10
# 200
# 2.0
# 2

# %%
# Changing variavle value

Price=200

# %%
print(Price)
# Out:
# 200

# %%
id(Price)
# Out:
# 140735164693640

# %%
Price=100

# %%
print(Price)
# Out:
# 100

# %%
id(Price)
# Out:
# 140735164690440

# %% [raw]
# #Concatenating Strings in Python
#
# String concatenation means joining two or more strings together.

# %%
s1='Hello'
s2='World'

print(s1+" "+s2)
# Out:
# Hello World

# %%
s1='I'
s2='Love'
s3='Coding'

print(s1+" "+s2+" "+s3)
# Out:
# I Love Coding

# %% [raw]
# Using f-strings (Modern & Best Practice)

# %%
name='Dravid'
age=30

print(f"My name is {name} and my age is {age}")
# Out:
# My name is Dravid and my age is 30

# %% [raw]
# Using format() Method

# %%
name='Dravid'
age='30'

# %%
print("My name is {} and I am {} years old".format(name,age))
# Out:
# My name is Dravid and I am 30 years old

# %%
name = "Dravid"

print("My name is {}".format(name))
# Out:
# My name is Dravid

# %%
name='Dravid'
age='30'
education='Graduation'
city='Agra'

# %%
print("My name is {} i am {} years old , I am residing in {} and completed my {} in 2015".format(name,age,city,education))
# Out:
# My name is Dravid i am 30 years old , I am residing in Agra and completed my Graduation in 2015

# %% [markdown]
# ## Using variable in calculation

# %%
length=100
width=200

Area= length*width

# %%
print(Area)
# Out:
# 20000

# %% [raw]
# Final Notes:
# >	Variables can store any type of data, including numbers, strings, lists, dictionaries, objects, etc.
# >	Variables are dynamic, meaning their type is automatically determined by the value assigned to them, and they can change type during execution.
