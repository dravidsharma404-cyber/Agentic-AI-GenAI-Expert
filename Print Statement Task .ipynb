# %% [raw]
# We are using print for getting output of multiple inputs

# %%
a=10
a
# Out:
# 10

# %%
a=10
b=20

# %%
a,b
# Out:
# (10, 20)

# %%
a
b
# Out:
# 20

# %%
print(a)
print(b)
# Out:
# 10
# 20

# %% [markdown]
# # Print result with string

# %%
num1=10
num2=20
add=num1+num2

# %%
print('The addition of', num1 , 'and' , num2,'is=', add)
# Out:
# The addition of 10 and 20 is= 30

# %%
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 10 and 20 is = 30

# %%
name='Dravid '
city='Agra'
age=30
course='FSDS'

# %%
print('My name is', name, 'I am residing in', city , 'I am', age , 'years old', 'and i enrolled in', course, 'NIT Course this year')
# Out:
# My name is Dravid I am residing in Agra I am 30 years old and i enrolled in FSDS NIT Course this year

# %%
print('My name is {} I am residing in {}, I am {} years old, and i enrolled in {} NIT Course this year'.format(name, city, age , course))
# Out:
# My name is Dravid I am residing in Agra, I am 30 years old, and i enrolled in FSDS NIT Course this year

# %%
print(name *5)
# Out:
# Dravid Dravid Dravid Dravid Dravid

# %% [markdown]
# # End in print() function

# %%
print('Hello')
print('How are you')
# Out:
# Hello
# How are you

# %%
# Here I want to print in a single row " Hello How are you"

# %%
print('Hello', end=' ')
print('How are you')
# Out:
# Hello How are you

# %%
# Or I can do

# %%
print('Hello', end=' $ ')
print('How are you')
# Out:
# Hello $ How are you

# %%
print('Hello', end=' ')
print('How are you')

# %%
# Or

# %%
print('Hello', end=' $ ')
print('How are you', end=' # ')
# Out:
# Hello $ How are you #

# %%
# Or

# %%
print('Hello', end=' $ Doller ')
print('How are you', end=' Rupee !')
# Out:
# Hello $ Doller How are you Rupee !

# %% [markdown]
# # Separator in print() function

# %%
print('Hi How are your', 'Dravid', sep=' @ ')
# Out:
# Hi How are your @ Dravid

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', sep=' @ ')
# Out:
# Hi @ How @ are @ your @ Dravid

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', sep=' <> ')
# Out:
# Hi <> How <> are <> your <> Dravid

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', sep=' * ')
# Out:
# Hi * How * are * your * Dravid

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', sep=' # ')
# Out:
# Hi # How # are # your # Dravid

# %%
# Print End & Seprate

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', end='?', sep=' # ' )
# Out:
# Hi # How # are # your # Dravid?

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', end='?', sep=',' )
# Out:
# Hi,How,are,your,Dravid?

# %%
print('Hi', 'How', 'are', 'your', 'Dravid', end='?', sep='_' )
# Out:
# Hi_How_are_your_Dravid?
