# %% [markdown]
# ## 1. Arithmetic Operators Practice

# %%
print(2+2)
print(4-2)
print(2*2)
print(7/2)
print(7//2)
print(8%3)
print(2**2)
# Out:
# 4
# 2
# 4
# 3.5
# 3
# 2
# 4

# %% [markdown]
# ## 2. Comparison Operators

# %%
print(10 > 5)
print(10 < 5)
print(10 == 10)
print(10 != 5)
print(5 >= 5)
print(3 <= 2)
# Out:
# True
# False
# True
# True
# True
# False

# %% [markdown]
# ##  3. Logical Operators

# %% [raw]
# What are Logical Operators?
#
# Logical operators are used to combine conditions.
#
# 👉 There are 3 main logical operators:
#
# and
# or
# not

# %% [raw]
# 1. and Operator
#
# 📌 Rule:
#
# 👉 Result is True only if BOTH conditions are True

# %%
print(True and True)   # True
print(True and False)  # False
# Out:
# True
# False

# %%
age=20
print(age > 18 and age < 25)
# Out:
# True

# %% [raw]
# age > 18 → True
# age < 25 → True
#
# 👉 Final: True

# %% [raw]
# 2. or Operator
#
# 📌 Rule:
#
# 👉 Result is True if ANY ONE condition is True

# %%
marks = 35
print(marks > 40 or marks > 30)
# Out:
# True

# %% [raw]
# 👉 Step:
#
# marks > 40 → False
# marks > 30 → True
# 👉 Final: True

# %% [raw]
# 3. not Operator
#
# 📌 Rule:
#
# 👉 It reverses the result

# %%
print(10 > 5)
# Out:
# True

# %%
print(not(10 > 5))
# Out:
# False

# %% [markdown]
# # Truth Table
#
# | A     | B     | A and B | A or B |
# | ----- | ----- | ------- | ------ |
# | True  | True  | True    | True   |
# | True  | False | False   | True   |
# | False | True  | False   | True   |
# | False | False | False   | False  |

# %%
print(False and something)
# Out:
# False

# %%
print(True or something)
# Out:
# True

# %%
print(True and False or True)
# Out:
# True

# %%
print(not(True and False))
# Out:
# True

# %%
print(5 > 3 and 2 < 1 or 10 > 5)
# Out:
# True

# %%
print(not(5 > 2 and 3 < 1))
# Out:
# True

# %%
a = 10
b = 5

# %%
print(a > b and b > 2)  #True and True = True
# Out:
# True

# %%
print(a < b or b == 5)  # False or True = True
# Out:
# True

# %%
print(not(a == 10))  # True = False
# Out:
# False

# %%
print(a > 5 and b < 10 or a < 5)  # True and True or False = True
# Out:
# True

# %% [markdown]
# # Problem 1: Age Eligibility

# %% [raw]
# 👉 A person can vote if:
#
# age ≥ 18
# and age ≤ 100

# %%
age=20

if age>=18 and age<=100:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Eligible for voting

# %%
age=18

if age>=18 and age<=100:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Eligible for voting

# %%
age=17.5

if age>=18 and age<=100:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Not eligible for voting

# %%
age=99

if age>=18 and age<=100:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Eligible for voting

# %%
age=101

if age>=18 and age<=100:
    print("Eligible for voting")
else:
    print("Not eligible for voting")
# Out:
# Not eligible for voting

# %% [markdown]
# ## Problem 2: Login System

# %% [raw]
# 👉 User can login if:
#
# username is correct
# AND password is correct

# %%
username='Dravid619193'
password='Agra@131313'

if username =='Dravid619193' and password=='Agra@131313':
    print("You are logged in")
else:
    print("username and password invalid")
# Out:
# You are logged in

# %%
username='Dravid619193'
password='Agra@131313'

if username =='Dravid69193' and password=='Agra@131313':
    print("You are logged in")
else:
    print("username and password invalid")
# Out:
# username and password invalid

# %%
username='Dravid619193'
password='Agra@131313'

if username =='Dravid619193' and password=='agra@131313':
    print("You are logged in")
else:
    print("username and password invalid")
# Out:
# username and password invalid

# %% [markdown]
# ## Problem 3: Discount System

# %%
Min=1000

if Min>=1000:
    print("Eligible for 5% discount")
else:
    print("Not Eligible for discount")
# Out:
# Eligible for 5% discount

# %%
Min=5000

if Min>=1000:
    print("Eligible for 5% discount")
else:
    print("Not Eligible for discount")
# Out:
# Eligible for 5% discount

# %%
Min=999

if Min>=1000:
    print("Eligible for 5% discount")
else:
    print("Not Eligible for discount")
# Out:
# Not Eligible for discount

# %%
purchase = 1000
is_card_used = True

if purchase >= 1000 or is_card_used:
    print("Eligible for 5% discount")
else:
    print("Not Eligible for discount")
# Out:
# Eligible for 5% discount

# %%
Purchase_Amount=1000
Card_used=True

if Purchase_Amount>=1000 or is_card_used:
    print("Eligible for 5% discount")
else:
    print("Not Eligible for discount")
# Out:
# Eligible for 5% discount

# %% [markdown]
# ## Problem 4: Even & Positive Number

# %%
num=4

if num>0 and num%2==0:
    print("Even Number")
else:
    print("Odd NUmber")
# Out:
# Even Number

# %%
num=7

if num>0 and num%2==0:
    print("Even Number")
else:
    print("Odd NUmber")
# Out:
# Odd NUmber

# %%
num=192939

if num>0 and num%2==0:
    print("Even Number")
else:
    print("Odd NUmber")
# Out:
# Odd NUmber

# %%
num=32232

if num>0 and num%2==0:
    print("Even Number")
else:
    print("Odd NUmber")
# Out:
# Even Number

# %% [markdown]
# ## Problem 5: Not Operator Use

# %%
num=5

if not(num < 0):
    print("Number is positive or zero")
# Out:
# Number is positive or zero

# %%
num=-1

if not(num < 0):
    print("Number is positive or zero")
else:
    print("Number is negative")
# Out:
# Number is negative

# %% [markdown]
# # PART 2: If-Else + Logical Combo Problems

# %% [markdown]
# ## Problem 6: Pass or Fail

# %% [raw]
# Pass if marks ≥ 40
# AND attendance ≥ 75

# %%
marks=75
attendence='70%'

if marks >= 75 and attendence>='80%':
    print("Pass")
else:
    print("Fail")
# Out:
# Fail

# %%
marks=75
attendence='90%'

if marks >= 75 and attendence>='80%':
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %% [markdown]
# ## Problem 7: Grade System

# %%
marks=75

if marks>=90:
    print(" Grade A ")
elif marks>=80 and marks<=89:
    print(" Grade B ")
elif marks>=70 and marks<=79:
    print(" Grade C ")
elif marks<70:
    print("Fail")
# Out:
#  Grade C

# %%
marks=99

if marks>=90:
    print(" Grade A ")
elif marks>=80 and marks<=89:
    print(" Grade B ")
elif marks>=70 and marks<=79:
    print(" Grade C ")
elif marks<70:
    print("Fail")
# Out:
#  Grade A

# %%
marks=55

if marks>=90:
    print(" Grade A ")
elif marks>=80 and marks<=89:
    print(" Grade B ")
elif marks>=70 and marks<=79:
    print(" Grade C ")
elif marks<70:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# ## Problem 8: Largest of 3 Numbers

# %%
a = 10
b = 20
c = 15

# %%
if a>b and a>c:
    print(" A is largest number in the given numbers ")
elif b>a and b>c:
    print(" B is largest number in the given numbers ")
elif c>a and c>b:
    print(" C is largest number in the given numbers ")
# Out:
#  B is largest number in the given numbers

# %% [markdown]
# ## Problem 9: Leap Year (Interview Classic 🔥)

# %%
👉 Condition:

divisible by 4 AND not by 100
OR divisible by 400

# %%
Year=2026

if (Year % 4 ==0 and Year%100 !=0) or (Year % 400 == 0):
    print("Leap Year")
else:
    print("Not a leap year")
# Out:
# Not a leap year

# %%
Year=2024

if (Year % 4 ==0 and Year%100 !=0) or (Year % 400 == 0):
    print("Leap Year")
else:
    print("Not a leap year")
# Out:
# Leap Year

# %% [raw]
# ✅ Rule 1:
# Divisible by 4
# 👉 Year % 4 == 0
#
# ❌ Rule 2:
# BUT not divisible by 100
# 👉 Year % 100 != 0
#
# 🔥 Special Case:
# If divisible by 400 → ALWAYS leap year
# 👉 Year % 400 == 0
#
#
# (Year % 4 == 0 and Year % 100 != 0) or (Year % 400 == 0)
#
#
# 2024 % 4 == 0  → True
#
# 2024 % 100 != 0 → True
#
# True AND True = True
#
# 2024 % 400 == 0 → False
#
# (True) OR (False) = True

# %%
Year=1900

if (Year % 4 ==0 and Year%100 !=0) or (Year % 400 == 0):
    print("Leap Year")
else:
    print("Not a leap year")
# Out:
# Not a leap year

# %% [raw]
# divisible by 4 ✅
# divisible by 100 ❌ (problem)
# NOT divisible by 400 ❌
#
# 👉 So:

# %%
1900%4
# Out:
# 0

# %%
1900%100
# Out:
# 0

# %%
1900%400
# Out:
# 300

# %% [raw]
# 👉 Leap Year =
#
# (divisible by 4 AND NOT divisible by 100)
# OR
# (divisible by 400)
#
#
# False or False = False

# %% [markdown]
# ## Problem 10: Username OR Email Login

# %%
username="user@123"
email="user@pb.com"
Input_data="user@pb.com"

if Input_data==username or Input_data==email:
    print("Login Allowed")
else:
    print("Invalid Input")
# Out:
# Login Allowed

# %%
username="user@123"
email="user@pb.com"
Input_data="use@pb.com"

if Input_data==username or Input_data==email:
    print("Login Allowed")
else:
    print("Invalid Input")
# Out:
# Invalid Input

# %%
username="user@123"
email="user@pb.com"
Input_data="user@123"

if Input_data==username or Input_data==email:
    print("Login Allowed")
else:
    print("Invalid Input")
# Out:
# Login Allowed

# %%
age = 22
salary = 30000

if age > 21 and salary > 25000:
    print("Eligible for loan")
else:
    print("Not eligible")
# Out:
# Eligible for loan

# %%
num=15

if num%3==0 and num%5==0:
    print("Divisible by both")
elif num%3==0 or num%5==0:
    print("Divisible by any one only")
else:
    print("Not divisible by both")
# Out:
# Divisible by both

# %%
num=9

if num%3==0 and num%5==0:
    print("Divisible by both")
elif num%3==0 or num%5==0:
    print("Divisible by any one only")
else:
    print("Not divisible by both")
# Out:
# Divisible by any one only

# %%
num=2

if num%3==0 and num%5==0:
    print("Divisible by both")
elif num%3==0 or num%5==0:
    print("Divisible by any one only")
else:
    print("Not divisible by both")
# Out:
# Not divisible by both

# %%
x=8

if x > 2 and x < 10:
    if x % 2==0:
        print("Even in range")
    else:
        print("Odd in Range")
# Out:
# Even in range

# %%
x=3

if x > 2 and x < 100:
    if x % 2==0:
        print("Even in range")
    else:
        print("Odd in Range")
# Out:
# Odd in Range

# %%
x=9

if x > 2 and x < 100:
    if x % 2==0:
        print("Even in range")
    else:
        print("Odd in Range")
# Out:
# Odd in Range
