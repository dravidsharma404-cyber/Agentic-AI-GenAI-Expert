# %% [markdown]
# # PART 1: Python Basics (Calculator)

# %% [raw]
# Python can work like a calculator:

# %%
print(24 + 2)
print(50 - 5*6)
print((50 - 5*6) / 4)
# Out:
# 26
# 20
# 5.0

# %% [raw]
# Simple Understanding:
# + → add
# - → subtract
# * → multiply
# / → always gives decimal (float)
# // → gives integer (floor division)
# % → gives remainder
# ** → power

# %% [markdown]
# ## ✅ Practice Set (Level 1)

# %%
print(2+2)
print(4-2)
print(2*2)
print(4/2)
print(2//2)
print(4%2)
# Out:
# 4
# 2
# 4
# 2.0
# 1
# 0

# %%
print(2**4)
# Out:
# 16

# %%
print(2**8)  #2 × 2 × 2 × 2 × 2 × 2 × 2 × 2
# Out:
# 256

# %% [markdown]
# # PART 2: Variables

# %%
width = 20
height = 5 * 9
print(width * height)
# Out:
# 900

# %% [markdown]
# # PART 3: Strings (Most Important 🔥)

# %%
"Hello"
'Python'
# Out:
# 'Python'

# %%
print('Hello')('World')
# Out:
# Hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print('Hello')('World')
#
# TypeError: 'NoneType' object is not callable

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello', end=" ")
print('World')
# Out:
# Hello World

# %% [raw]
# ## Escape Characters

# %%
print("I am \"bad\"")
# Out:
# I am "bad"

# %%
print("I am \"Good\" or \"Bad\"")
# Out:
# I am "Good" or "Bad"

# %%
print("I am \"Good\" or \"Bad\"")
# Out:
# I am "Good" or "Bad"

# %%
print("I am \"Good\"")
# Out:
# I am "Good"

# %% [markdown]
# ## New Line

# %%
print("Hello\n World")
# Out:
# Hello
#  World

# %%
print("My\n Name\n is\n Dravid\n Sharma\n ")
# Out:
# My
#  Name
#  is
#  Dravid
#  Sharma

# %% [markdown]
# ## Raw String

# %%
print(r"C:\new\file")  #👉 r means ignore special characters
# Out:
# C:\new\file

# %%
print("C:\new\file")
# Out:
# C:
# ewile

# %%
print(r"C:\new\file")
# Out:
# C:\new\file

# %% [markdown]
# # Multi-line String

# %%
print('''Hi 
How are You
I am 
Good 
How are you''')
# Out:
# Hi
# How are You
# I am
# Good
# How are you

# %% [markdown]
# # String Operations

# %%
print("Hello " + " World")
# Out:
# Hello  World

# %%
print("Hello "*5)
# Out:
# Hello Hello Hello Hello Hello

# %%
print("My Name is " + "Dravid Sharma " + " How are you" + " ? " )
# Out:
# My Name is Dravid Sharma  How are you ?

# %%
print("Whoo "*5)
# Out:
# Whoo Whoo Whoo Whoo Whoo

# %%
print("Hello \n Python")  # \n means new line
# Out:
# Hello
#  Python

# %%
print("D:\folder\new")
# Out:
# D:older
# ew

# %%
print(r"D:\folder\new")    # r means avoid special character and give output as it is
# Out:
# D:\folder\new
