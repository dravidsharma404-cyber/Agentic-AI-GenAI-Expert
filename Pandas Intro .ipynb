# %% [markdown]
# Pandas == Library which handles datadrames
#
# Dataset == Table === Rows and columm
# database == Multiple tables
#
#
# Main features:
# 1. Handles missing data
# 2. Insert and deletion data
# 3. Data alignments
# 4. Group-by functions ( For multiple elemetns - Exp = Many co companies of a parent company )
# 5. Indexing & Slicing
# 6. Merging the dataset
# 7. Reshaping & Pivot
# 8. To read - Excel, hdf5, html, xml, pdf
# 9. Can use time series
# 10. Hierarchical labeling

# %% [raw]
# Raw Data = May have missing value
# Clean Data  = No Missing values
#
#
# # When a person cleaning raw data its called data cleaning Or Data cleansing ( Data analyst , Data Scientist etc. )

# %% [markdown]
# ## Work Flow
#
#
# Raw >> Data cleaning >> datadet >> mlmodel >> model will predict with live data >> Frontend >> Deployement >> mlops >> cicd pipeline

# %% [raw]
# Excel = Dataset
#
# In Excel = Row
# In Data science = Records
#
# In Excel = Columns
# In Data Science = Attributes , Feature , Variable
#
# Argument = Parameters
# Package = Library
#
# Functions without arguement
# Functions witho arguement

# %% [markdown]
# # Country's GDP/Economy Analysis

# %% [raw]
# This Dataset contains = 195 records & 5 attributes
#
# 2 are numerical attributes   - Numbers
# 3 are categorical attributes   - Text
