# %% [raw]
# List []  - Mutable  * Can do changes
# Tuple ()  - Immutable * Can't do changes

# %% [markdown]
# # Tuple

# %%
t=()
t
# Out:
# ()

# %%
t1=(20,30,40,50,60)
t1
# Out:
# (20, 30, 40, 50, 60)

# %%
t2=(10,5.5,True,2+3j, "Dravid")
t2
# Out:
# (10, 5.5, True, (2+3j), 'Dravid')

# %% [raw]
# # User can defined multiple data types
#
# # Duplication is also allowed

# %%
print(t1)
print(t2)
# Out:
# (20, 30, 40, 50, 60)
# (10, 5.5, True, (2+3j), 'Dravid')

# %%
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t1.count(20)
# Out:
# 1

# %%
t1.index(20)
# Out:
# 0

# %%
t1.index(30)
# Out:
# 1

# %%
t1[:2]
# Out:
# (20, 30)

# %%
t1[2]=30
t1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t1[2]=30
#       2 t1
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1*3
# Out:
# (20, 30, 40, 50, 60, 20, 30, 40, 50, 60, 20, 30, 40, 50, 60)

# %% [markdown]
# ## Practice

# %%
t1=(10,20,30,40,50,60) # Integers
t2=("Ram", "Shyam", "Dravid", "Kuldip", "Amit") # String
t3=(70,20.5,True,2+3j) # Mixed data
t4=(10,20,30,(10,20),(40,50),60) # Nested tuple

print(t1)
print(t2)
print(t3)
print(t4)
# Out:
# (10, 20, 30, 40, 50, 60)
# ('Ram', 'Shyam', 'Dravid', 'Kuldip', 'Amit')
# (70, 20.5, True, (2+3j))
# (10, 20, 30, (10, 20), (40, 50), 60)

# %% [markdown]
# ## Tuple Indexing

# %%
t1
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t1[:2])
# Out:
# (10, 20)

# %%
print(t1[::2])
# Out:
# (10, 30, 50)

# %%
print(t1[1:5:2])
# Out:
# (20, 40)

# %%
t1[1]
# Out:
# 20

# %%
t1[-1]
# Out:
# 60

# %%
t2[0:6:2]
# Out:
# ('Ram', 'Dravid', 'Amit')

# %%
t2[-2]
# Out:
# 'Kuldip'

# %%
print(t1[:])
print(t2[:])
# Out:
# (10, 20, 30, 40, 50, 60)
# ('Ram', 'Shyam', 'Dravid', 'Kuldip', 'Amit')

# %%
del t1[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 del t1[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
for i in t1:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60

# %%
for i in enumerate(t1):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 40)
# (4, 50)
# (5, 60)

# %%
for i in enumerate(t2):
    print(i)
# Out:
# (0, 'Ram')
# (1, 'Shyam')
# (2, 'Dravid')
# (3, 'Kuldip')
# (4, 'Amit')

# %%
for i in enumerate(t3):
    print(i)
# Out:
# (0, 70)
# (1, 20.5)
# (2, True)
# (3, (2+3j))

# %%
for i in enumerate(t4):
    print(i)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, (10, 20))
# (4, (40, 50))
# (5, 60)

# %%
10 in t1
# Out:
# True

# %%
if 'Dravid' in t2:
    print("It is here")
else:
    print("Not find")
# Out:
# It is here

# %%
t2.index('Dravid')
# Out:
# 2

# %%
t4.index(10)
# Out:
# 0

# %%
t5=(20,10,40,30,100,50)
t5
# Out:
# (20, 10, 40, 30, 100, 50)

# %%
sorted(t5)
# Out:
# [10, 20, 30, 40, 50, 100]

# %%
sorted(t5,reverse=True)
# Out:
# [100, 50, 40, 30, 20, 10]
